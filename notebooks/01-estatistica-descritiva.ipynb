# %% [markdown]
# # Estatistica Descritivas de Dados

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Conjunto de Dados - Pinguins

# %%
df = sns.load_dataset('penguins')

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# ### Dicionario de Dados - Pinguins

# %%
df_dict = pd.DataFrame([
{
"variavel":"species",
"descricao": "Especie do pinguin",
"tipo":"qualitativa",
"subtipo":"nominal",
},{
"variavel":"island",
"descricao":"Ilha onde vive o pinguin",
"tipo":"qualitativa",
"subtipo":"nominal",
},{
"variavel":"bill_length_mm",
"descricao":"Comprimento do bico do pinguin em milimetros",
"tipo":"quantitativa",
"subtipo":"continua",
},{
"variavel":"bill_depth_mm",
"descricao":"Profundidade do bico do pinguin em milimetros",
"tipo":"quantitativa",
"subtipo":"continua",
},{
"variavel":"flipper_length_mm",
"descricao":"Comprimento da nadadeira do pinguin em milimetros",
"tipo":"quantitativa",
"subtipo":"continua",
},{
"variavel":"body_mass_g",
"descricao":"Peso do pinguin em gramas",
"tipo":"quantitativa",
"subtipo":"continua",
},{
"variavel":"sex",
"descricao":"Sexo do pinguin",
"tipo":"qualitativa",
"subtipo":"nominal",
}
])
df_dict
# Out:
#             variavel                                          descricao  \
# 0            species                                 Especie do pinguin
# 1             island                           Ilha onde vive o pinguin
# 2     bill_length_mm       Comprimento do bico do pinguin em milimetros
# 3      bill_depth_mm      Profundidade do bico do pinguin em milimetros
# 4  flipper_length_mm  Comprimento da nadadeira do pinguin em milimetros
# 5        body_mass_g                          Peso do pinguin em gramas
# 6                sex                                    Sexo do pinguin
#
#            tipo   subtipo
# 0   qualitativa   nominal
# 1   qualitativa   nominal
# 2  quantitativa  continua
# 3  quantitativa  continua
# 4  quantitativa  continua
# 5  quantitativa  continua
# 6   qualitativa   nominal

# %% [markdown]
# ### Estatisticas qualitativas

# %%
df[['species','island','sex']].mode()
# Out:
#   species  island   sex
# 0  Adelie  Biscoe  Male

# %% [markdown]
# ### Estatisticas quantitativas

# %%
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
qualitative_vars = ['species','island','sex']

for variavel in qualitative_vars:
	valores_unicos = df[variavel].unique()
	for valor in valores_unicos:
		print(f"{variavel} - {valor}")
		subamostra = df[df[variavel] == valor]
		display(subamostra.describe())
		print("-"*80)
# Out:
# species - Adelie
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      151.000000     151.000000         151.000000   151.000000
# mean        38.791391      18.346358         189.953642  3700.662252
# std          2.663405       1.216650           6.539457   458.566126
# min         32.100000      15.500000         172.000000  2850.000000
# 25%         36.750000      17.500000         186.000000  3350.000000
# 50%         38.800000      18.400000         190.000000  3700.000000
# 75%         40.750000      19.000000         195.000000  4000.000000
# max         46.000000      21.500000         210.000000  4775.000000
# --------------------------------------------------------------------------------
# species - Chinstrap
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count       68.000000      68.000000          68.000000    68.000000
# mean        48.833824      18.420588         195.823529  3733.088235
# ...

# %% [markdown]
# ## Conjunto de Dados - Tips

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Dicionario de Dados - Tips (Gorjetas)

# %%
df_dict = pd.DataFrame([
{
"variavel":"total_bill",
"descricao": "Valor total da conta",
"tipo":"quantitativa",
"subtipo":"continua",
},{
"variavel":"tip",
"descricao": "Valor da gorjeta",
"tipo":"quantitativa",
"subtipo":"continua",
},{
"variavel":"sex",
"descricao":"sexo do cliente",
"tipo":"qualitativa",
"subtipo":"nominal",
},{
"variavel":"smoker",
"descricao":"Indicação se a pessoa é ou não fumante",
"tipo":"qualitativa",
"subtipo":"nominal",
},{
"variavel":"day",
"descricao":"Dia da semana('Thur','Fri','Sat','Sun')",
"tipo":"quantitativa",
"subtipo":"continua",
},{
"variavel":"time",
"descricao":"Hora da refeição('Dinner','Lunch')",
"tipo":"qualitativa",
"subtipo":"nominal",
},{
"variavel":"size",
"descricao":"Quantidade de pessoas na mesa",
"tipo":"quantitativa",
"subtipo":"continua",
}
])
df_dict
# Out:
#      variavel                                descricao          tipo   subtipo
# 0  total_bill                     Valor total da conta  quantitativa  continua
# 1         tip                         Valor da gorjeta  quantitativa  continua
# 2         sex                          sexo do cliente   qualitativa   nominal
# 3      smoker   Indicação se a pessoa é ou não fumante   qualitativa   nominal
# 4         day  Dia da semana('Thur','Fri','Sat','Sun')  quantitativa  continua
# 5        time       Hora da refeição('Dinner','Lunch')   qualitativa   nominal
# 6        size            Quantidade de pessoas na mesa  quantitativa  continua

# %% [markdown]
# ### Estatisticas qualitativas

# %%
df[['sex','smoker','day','time']].mode()
# Out:
#     sex smoker  day    time
# 0  Male     No  Sat  Dinner

# %% [markdown]
# ### Estatisticas quantitativas

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
qualitative_vars = ['sex','smoker','day','time']

for variavel in qualitative_vars:
	valores_unicos = df[variavel].unique()
	for valor in valores_unicos:
		print(f"{variavel} - {valor}")
		subamostra = df[df[variavel] == valor]
		display(subamostra.describe())
		print("-"*80)
# Out:
# sex - Female
#        total_bill        tip       size
# count   87.000000  87.000000  87.000000
# mean    18.056897   2.833448   2.459770
# std      8.009209   1.159495   0.937644
# min      3.070000   1.000000   1.000000
# 25%     12.750000   2.000000   2.000000
# 50%     16.400000   2.750000   2.000000
# 75%     21.520000   3.500000   3.000000
# max     44.300000   6.500000   6.000000
# --------------------------------------------------------------------------------
# sex - Male
#        total_bill         tip        size
# count  157.000000  157.000000  157.000000
# mean    20.744076    3.089618    2.630573
# std      9.246469    1.489102    0.955997
# min      7.250000    1.000000    1.000000
# 25%     14.000000    2.000000    2.000000
# 50%     18.350000    3.000000    2.000000
# 75%     24.710000    3.760000    3.000000
# max     50.810000   10.000000    6.000000
# --------------------------------------------------------------------------------
# smoker - No
# ...
